# %% [markdown]
# ## Male and Female populations by city
# Program enrolled male and female population counts. Dataset should be taken into Tableau for some work

# %%
import pandas as pd

# %%
def wrangle(filepath):
    df = pd.read_csv(filepath)
    df.drop(columns = 'Unnamed: 0', inplace = True)
    return df

# %%
df = wrangle(r'C:\Users\Alex Lucchesi\OneDrive\Documents\GitHub\homelessness_project\src\cleaned_datasets\2019_cc_alldata.csv')
df.head()
# Out:
#    sumlev  state  county stname          ctyname  year  agegrp  tot_pop  \
# 0      50     48       1  Texas  Anderson County     1       0    58458
# 1      50     48       1  Texas  Anderson County     1       1     3135
# 2      50     48       1  Texas  Anderson County     1       2     3258
# 3      50     48       1  Texas  Anderson County     1       3     3156
# 4      50     48       1  Texas  Anderson County     1       4     3107
#
#    tot_male  tot_female  ...  hwac_male  hwac_female  hbac_male  hbac_female  \
# 0     35521       22937  ...       5784         2707        321          129
# 1      1566        1569  ...        385          313         22           27
# 2      1729        1529  ...        375          324         17           16
# 3      1573        1583  ...        283          315         21           17
# 4      1676        1431  ...        324          255          7           12
#
# ...

# %%
l = []
for col in df.columns:
    if df[col].nunique() == 1:
        l.append(col)
l.pop()
df.drop(columns = l, inplace = True)

# %%
df.columns
# Out:
# Index(['county', 'stname', 'ctyname', 'year', 'agegrp', 'tot_pop', 'tot_male',
#        'tot_female', 'wa_male', 'wa_female', 'ba_male', 'ba_female', 'ia_male',
#        'ia_female', 'aa_male', 'aa_female', 'na_male', 'na_female', 'tom_male',
#        'tom_female', 'wac_male', 'wac_female', 'bac_male', 'bac_female',
#        'iac_male', 'iac_female', 'aac_male', 'aac_female', 'nac_male',
#        'nac_female', 'nh_male', 'nh_female', 'nhwa_male', 'nhwa_female',
#        'nhba_male', 'nhba_female', 'nhia_male', 'nhia_female', 'nhaa_male',
#        'nhaa_female', 'nhna_male', 'nhna_female', 'nhtom_male', 'nhtom_female',
#        'nhwac_male', 'nhwac_female', 'nhbac_male', 'nhbac_female',
#        'nhiac_male', 'nhiac_female', 'nhaac_male', 'nhaac_female',
#        'nhnac_male', 'nhnac_female', 'h_male', 'h_female', 'hwa_male',
#        'hwa_female', 'hba_male', 'hba_female', 'hia_male', 'hia_female',
#        'haa_male', 'haa_female', 'hna_male', 'hna_female', 'htom_male',
# ...

# %%
df1 = wrangle(r'C:\Users\Alex Lucchesi\OneDrive\Documents\GitHub\homelessness_project\src\cleaned_datasets\COVID_case_count_data.csv')
df1.head()
# Out:
#      county  confirmed_cases  probable_cases  fatalities
# 0  Anderson           4954.0          2774.0         171
# 1   Andrews           2637.0             0.0          52
# 2  Angelina           6546.0          6656.0         356
# 3   Aransas           1920.0           556.0          56
# 4    Archer            937.0           140.0          14

# %%
df2 = pd.read_csv(r'C:\Users\Alex Lucchesi\OneDrive\Documents\GitHub\homelessness_project\src\cleaned_datasets\COVID_data_Texas_by_county.csv', index_col = 'Unnamed: 0')
df2.index.rename('date', inplace = True)
df2.head()
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 572 entries, 2020-03-06 to 2021-09-28
# Columns: 255 entries, anderson to total
# dtypes: float64(255)
# memory usage: 1.1+ MB

# %%
df2.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 572 entries, 2020-03-06 to 2021-09-28
# Data columns (total 255 columns):
#  #    Column         Dtype
# ---   ------         -----
#  0    anderson       float64
#  1    andrews        float64
#  2    angelina       float64
#  3    aransas        float64
#  4    archer         float64
#  5    armstrong      float64
#  6    atascosa       float64
#  7    austin         float64
#  8    bailey         float64
#  9    bandera        float64
#  10   bastrop        float64
#  11   baylor         float64
#  12   bee            float64
#  13   bell           float64
#  14   bexar          float64
#  15   blanco         float64
#  16   borden         float64
#  17   bosque         float64
#  18   bowie          float64
#  19   brazoria       float64
#  20   brazos         float64
#  21   brewster       float64
#  22   briscoe        float64
#  23   brooks         float64
#  24   brown          float64
#  25   burleson       float64
# ...
